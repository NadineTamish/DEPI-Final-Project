# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# %cd darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15873, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 15873 (delta 3), reused 0 (delta 0), pack-reused 15863 (from 3)
# Receiving objects: 100% (15873/15873), 14.47 MiB | 14.71 MiB/s, done.
# Resolving deltas: 100% (10686/10686), done.
# /content/darknet

# %%
# Install and configure Kaggle
# !pip install kaggle
from google.colab import files

# Upload kaggle.json
files.upload()

# Fix possible "Directory not empty" error
# !rm -f ~/.kaggle/kaggle.json
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Download dataset
# !kaggle datasets download -d amitkumargurjar/car-detection-and-tracking-dataset

# Verify if the file exists
# !ls -lh

# Unzip the dataset (if downloaded correctly)
# !unzip -q car-detection-and-tracking-dataset.zip -d /content/dataset/
# Out:
# ...
#      <input type="file" id="files-87eda367-cfe0-4481-bf0d-182742e67af0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87eda367-cfe0-4481-bf0d-182742e67af0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %%writefile /content/dataset/dataset.yaml
# train: /content/dataset/archive/train/images
# val: /content/dataset/archive/val/images
# nc: 1
# names: ['car']
# Out:
# Writing /content/dataset/dataset.yaml

# %%
# !cat /content/dataset/dataset.yaml
# Out:
# train: /content/dataset/archive/train/images
# val: /content/dataset/archive/val/images
# nc: 1
# names: ['car']

# %%
#install yolo
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # Load pre-trained model
model.train(data="/content/dataset/dataset.yaml", epochs=50, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 399MB/s]
# Ultralytics 8.3.94 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
#it will work on vscode
import cv2
import matplotlib.pyplot as plt
model = YOLO("/content/darknet/runs/detect/train/weights/best.pt")  # Load the best-trained model
results = model("/content/DSC_5903.jpg", save=True,show=True)  # Perform inference on
print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0bcf2f4f03b9> in <cell line: 0>()
#       1 import cv2
#       2 import matplotlib.pyplot as plt
# ----> 3 model = YOLO("/content/darknet/runs/detect/train/weights/best.pt")  # Load the best-trained model
#       4 results = model("/content/DSC_5903.jpg", save=True,show=True)  # Perform inference on
#       5 print(results)
#
# NameError: name 'YOLO' is not defined
